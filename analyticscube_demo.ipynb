# %%
import acobjects as ao
app = ao.App(open_in_browser=True)
#app.view
# Out:
# WARNING:param.Compute Stacks: Setting non-parameter attribute items=[('Add', 'add'), ('Delete', 'delete'), ('Analyze', 'analyze')] using a mechanism intended only for parameters
# WARNING:param.Compute Stacks: Setting non-parameter attribute tag=first using a mechanism intended only for parameters
# WARNING:param.Add Block: Setting non-parameter attribute items=[('Add', 'add'), ('Delete', 'delete'), ('Analyze', 'analyze')] using a mechanism intended only for parameters
# WARNING:param.Add Block: Setting non-parameter attribute tag=first using a mechanism intended only for parameters
# WARNING:param.WidgetBox01822: Setting non-parameter attribute tag=first using a mechanism intended only for parameters
# WARNING:param.Clear Blocks: Setting non-parameter attribute tag=first using a mechanism intended only for parameters
# WARNING:param.Save Program: Setting non-parameter attribute tag=first using a mechanism intended only for parameters
# ...
